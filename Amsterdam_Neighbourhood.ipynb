# %% [markdown]
# # IBM Applied Data Science Capstone
# ### Week 5
# **Opening a new Indian restaurant in Amsterdam, Netherlands**
# - Build a dataframe of neighborhoods in Amsterdam, Netherlands from Wikipedia page
# - Get the latitude longitude details of each neighborhood
# - Get the venue data for each neighborhood using Foursquare API
# - Cluster the neighbourhood
# - Choose the best neighbourhood

# %% [markdown]
# ### ** Importing Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import geocoder
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print("Libraries imported.")
# Out:
# Libraries imported.

# %% [markdown]
# #### 2. Web scraping through Wikipedia page

# %%
# send the GET request
data = requests.get('https://en.wikipedia.org/wiki/Category:Neighbourhoods_of_Amsterdam').text
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')
# create neighbourhood list to store table data
Neighbourhoods = []
# append the data into the list
for row in soup.find_all("div", class_="mw-category-generated")[0].findAll("li"):
    Neighbourhoods.append(row.text)
amsterdam_df = pd.DataFrame({"Neighbourhoods": Neighbourhoods})
amsterdam_df.drop(0,0,inplace=True)
amsterdam_df['Neighbourhoods'] = amsterdam_df['Neighbourhoods'].str.replace(" \(Amsterdam\)","")
amsterdam_df['Neighbourhoods'] = amsterdam_df['Neighbourhoods'].str.replace(" \(neighbourhood\)","")
amsterdam_df.head()
# Out:
#            Neighbourhoods
# 1          Admiralenbuurt
# 2              Amsteldorp
# 3      Amsterdam Oud-West
# 4      Amsterdam Oud-Zuid
# 5  Amsterdam Science Park

# %%
# print the number of rows of the dataframe
amsterdam_df.shape
# Out:
# (105, 1)

# %% [markdown]
# ## **Get latitude longitude details

# %%
# define a function to get coordinates
def get_latlng(neighbourhoods):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Amsterdam, Netherlands'.format(neighbourhoods))
        lat_lng_coords = g.latlng
        lat = lat_lng_coords[0]
        long = lat_lng_coords[1]
    return neighbourhoods,lat,long

#lat_lng_coords

# %%
# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighbourhoods) for neighbourhoods in amsterdam_df["Neighbourhoods"].tolist() ]

# %%
# create temporary dataframe to populate the coordinates into Latitude and Longitude
df_coords = pd.DataFrame(coords, columns=['Neighbourhoods','Latitude', 'Longitude'])

# %%
amsterdam_df = df_coords
amsterdam_df.head()
# Out:
#            Neighbourhoods   Latitude  Longitude
# 0          Admiralenbuurt  52.372734   4.856363
# 1              Amsteldorp  52.360540   4.905160
# 2      Amsterdam Oud-West  52.365390   4.870220
# 3      Amsterdam Oud-Zuid  52.352350   4.877880
# 4  Amsterdam Science Park  52.354320   4.958030

# %%
CLIENT_ID = 'QBEOHTMYDSZGNPWZNKIMGAHL1BVY5KVZBJGFUPM3UDPN2JAF' # your Foursquare ID
CLIENT_SECRET = 'Q142X5G20QH1QKQEWWXLLF1KZDH4HD0LQVTNCQZH3VYEXJLL' # your Foursquare Secret
VERSION = '20180604'
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QBEOHTMYDSZGNPWZNKIMGAHL1BVY5KVZBJGFUPM3UDPN2JAF
# CLIENT_SECRET:Q142X5G20QH1QKQEWWXLLF1KZDH4HD0LQVTNCQZH3VYEXJLL

# %%
address = 'Amsterdam, NL'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 52.3745403 4.89797550561798

# %%
# create map of Amsterdam using latitude and longitude values
map_amsterdam = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, long, neighbourhoods in zip(amsterdam_df['Latitude'], amsterdam_df['Longitude'], amsterdam_df['Neighbourhoods']):
    label = '{}'.format(neighbourhoods)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_amsterdam)  
    
map_amsterdam
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### I am filtering my search only on restaurants and not going with other venue categories such as Shopping Mall, Grocery Store etc. We can definitely change the criteria for better analysis and judgement.

# %%
search_query = 'Restaurants'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurants .... OK!

# %%
radius = 500
LIMIT = 100

venues = []

for row in amsterdam_df.itertuples():
    neighbourhoods = getattr(row,'Neighbourhoods')
    lat = getattr(row,'Latitude')
    long = getattr(row,'Longitude')
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID,CLIENT_SECRET,lat,long,VERSION,search_query,radius,LIMIT)
    
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    # return only relevant information for each nearby venue
    for venue in results:
            venues.append((
            neighbourhoods,
            lat,
            long,
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
# convert the venues list into a new DataFrame
venues_df = pd.DataFrame(venues)

# define the column names
venues_df.columns = ['Neighbourhoods', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(venues_df.shape)
# Out:
# (2778, 7)

# %%
venues_df.head()
# Out:
#    Neighbourhoods   Latitude  Longitude           VenueName  VenueLatitude  \
# 0  Admiralenbuurt  52.372734   4.856363              Radijs      52.371049
# 1  Admiralenbuurt  52.372734   4.856363             Maz Mez      52.371231
# 2  Admiralenbuurt  52.372734   4.856363        Broodje Daan      52.373456
# 3  Admiralenbuurt  52.372734   4.856363   Kattencafé Kopjes      52.370556
# 4  Admiralenbuurt  52.372734   4.856363  Sapporo Ramen Sora      52.371294
#
#    VenueLongitude              VenueCategory
# 0        4.856756                     Bistro
# 1        4.857968  Middle Eastern Restaurant
# 2        4.853299              Deli / Bodega
# 3        4.855507                   Pet Café
# 4        4.855144           Ramen Restaurant

# %%
venues_df.groupby(['Neighbourhoods']).count()
# Out:
#                                      Latitude  Longitude  VenueName  \
# Neighbourhoods
# Admiralenbuurt                             29         29         29
# Amsteldorp                                 28         28         28
# Amsterdam Oud-West                         77         77         77
# Amsterdam Oud-Zuid                         41         41         41
# Amsterdam Science Park                      4          4          4
# Apollobuurt                                15         15         15
# Betondorp                                   2          2          2
# Binnenstad                                 43         43         43
# Bos en Lommer                              42         42         42
# Buiksloot                                   5          5          5
# Buikslotermeer                             18         18         18
# Buitenveldert                              21         21         21
# Bullewijk                                   9          9          9
# Burgwallen Oude Zijde                      97         97         97
# Chassébuurt                                37         37         37
# Cruquiuseiland                             33         33         33
# Czaar Peterbuurt                           22         22         22
# Dapperbuurt                                41         41         41
# De Aker                                     3          3          3
# De Pijp                                   100        100        100
# De Wallen                                  97         97         97
# Diamantbuurt                               32         32         32
# Duivelseiland                              55         55         55
# Eastern Docklands                          16         16         16
# Eendracht                                   3          3          3
# Floradorp                                  33         33         33
# Frederik Hendrikbuurt                      68         68         68
# Gaasperdam                                  7          7          7
# Geuzenveld                                 13         13         13
# Gouden Reael                                9          9          9
# Grachtengordel                             33         33         33
# Haarlemmerbuurt                            47         47         47
# Hoofddorppleinbuurt                        57         57         57
# Houthaven                                   6          6          6
# IJburg                                      6          6          6
# Indische Buurt                             11         11         11
# Java-eiland                                33         33         33
# Jodenbuurt                                 65         65         65
# Jordaan                                   100        100        100
# KNSM Island                                33         33         33
# Kadijken                                   33         33         33
# Kadoelen                                    1          1          1
# Kinkerbuurt                                32         32         32
# Kolenkit District                          22         22         22
# Landelijk Noord                            13         13         13
# Landlust                                    3          3          3
# Lastage                                    26         26         26
# Middelveldsche Akerpolder                   6          6          6
# Molenwijk                                   5          5          5
# Museumkwartier                             29         29         29
# NDSM                                        7          7          7
# Negen Straatjes                            33         33         33
# Nieuw Sloten                                4          4          4
# Nieuwe Pijp                                14         14         14
# Museumkwartier                                  29
# NDSM                                             7
# Negen Straatjes                                 33
# Nieuw Sloten                                     4
# Nieuwe Pijp                                     14
# Nieuwendammerdijk en Buiksloterdijk              5
# Olympisch Kwartier                              33
# Omval                                           21
# Oostelijke Eilanden                             30
# Oosterdokseiland                                33
# Oosterparkbuurt                                 41
# Oostoever                                        4
# Oostpoort                                       36
# Oostzanerwerf                                    2
# Osdorp                                           4
# Oud Osdorp                                       4
# Oud-Oost                                        35
# Oude Pijp                                      100
# Overhoeks                                       15
# Overtoombuurt                                   29
# Overtoomse Veld                                  5
# Plantage                                        43
# Prinses Irenebuurt                              15
# Ransdorp                                         1
# Rieteilanden                                    33
# Rivierenbuurt                                    4
# Schellingwoude                                   2
# Schinkelbuurt                                   55
# Slotermeer                                      17
# Slotervaart                                      9
# Spaarndammerbuurt                               31
# Staatsliedenbuurt                               21
# Stadionbuurt                                    17
# Steigereiland                                   33
# Teleport                                        22
# Transvaalbuurt                                  18
# Trompbuurt                                      65
# Tuindorp Oostzaan                                3
# Uilenburg                                       41
# Venserpolder                                     2
# Watergraafsmeer                                 35
# Waterwijk                                       35
# Weesperzijde                                    50
# Westelijke Eilanden                             30
# Westelijke Tuinsteden                           33
# Westerpark                                      34
# Willemspark                                     33
# Zeeburgereiland                                 33
# Zeeheldenbuurt                                  10
# Zuidas                                          37

# %% [markdown]
# #### Let's find out how many unique categories can be identified from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(venues_df['VenueCategory'].unique())))
# Out:
# There are 101 uniques categories.

# %% [markdown]
# #### Number of Indian restaurants across the neighbourhood

# %%
seriesObj = venues_df.apply(lambda x: True if x['VenueCategory'] == 'Indian Restaurant' else False, axis = 1)
numOfRows = len(seriesObj[seriesObj==True].index)
print(numOfRows)
# Out:
# 32

# %% [markdown]
# #### Count of restaurants category-wise

# %%
venues_df.groupby('VenueCategory').count()
# Out:
#                                  Neighbourhoods  Latitude  Longitude  \
# VenueCategory
# Afghan Restaurant                             2         2          2
# African Restaurant                           22        22         22
# American Restaurant                           4         4          4
# Argentinian Restaurant                       11        11         11
# Asian Restaurant                             46        46         46
# Australian Restaurant                         3         3          3
# Austrian Restaurant                           4         4          4
# BBQ Joint                                    15        15         15
# Bagel Shop                                   51        51         51
# Bakery                                      158       158        158
# Belgian Restaurant                            2         2          2
# Bistro                                       42        42         42
# Brasserie                                     1         1          1
# Brazilian Restaurant                          5         5          5
# Breakfast Spot                              112       112        112
# Buffet                                        7         7          7
# Burger Joint                                 51        51         51
# Burrito Place                                 3         3          3
# Cafeteria                                     7         7          7
# Café                                        201       201        201
# Cajun / Creole Restaurant                     1         1          1
# Caribbean Restaurant                          9         9          9
# Caucasian Restaurant                          1         1          1
# Chinese Restaurant                           66        66         66
# Cigkofte Place                                1         1          1
# Comfort Food Restaurant                       6         6          6
# Creperie                                     18        18         18
# Deli / Bodega                                48        48         48
# Dim Sum Restaurant                            2         2          2
# Diner                                        26        26         26
# Doner Restaurant                              6         6          6
# Donut Shop                                    7         7          7
# Dumpling Restaurant                           1         1          1
# Dutch Restaurant                             11        11         11
# Eastern European Restaurant                   2         2          2
# Empanada Restaurant                           1         1          1
# Ethiopian Restaurant                          6         6          6
# Falafel Restaurant                           13        13         13
# Fast Food Restaurant                         29        29         29
# Fish & Chips Shop                            12        12         12
# Fondue Restaurant                             1         1          1
# Food                                          3         3          3
# Food Court                                    4         4          4
# Food Stand                                    7         7          7
# Food Truck                                   15        15         15
# French Restaurant                            73        73         73
# Fried Chicken Joint                           2         2          2
# Friterie                                      9         9          9
# Gastropub                                    55        55         55
# German Restaurant                             4         4          4
# Greek Restaurant                             33        33         33
# Himalayan Restaurant                          1         1          1
# Indian Chinese Restaurant                     1         1          1
# Indian Restaurant                            32        32         32
# Indonesian Restaurant                        65        65         65
# Irish Pub                                     3         3          3
# Italian Restaurant                          211       211        211
# Japanese Restaurant                          44        44         44
# Kebab Restaurant                              1         1          1
# Korean Restaurant                             1         1          1
# Latin American Restaurant                     5         5          5
# Lebanese Restaurant                           1         1          1
# Malay Restaurant                              7         7          7
# Mediterranean Restaurant                     50        50         50
# Mexican Restaurant                           18        18         18
# Middle Eastern Restaurant                    25        25         25
# Modern European Restaurant                   10        10         10
# Molecular Gastronomy Restaurant               3         3          3
# Moroccan Restaurant                           9         9          9
# Noodle House                                  5         5          5
# North Indian Restaurant                       5         5          5
# Paella Restaurant                             2         2          2
# Persian Restaurant                            1         1          1
# Peruvian Restaurant                           1         1          1
# Pet Café                                      2         2          2
# Pizza Place                                 115       115        115
# Portuguese Restaurant                         2         2          2
# Ramen Restaurant                             16        16         16
# Restaurant                                  346       346        346
# Salad Place                                  19        19         19
# Sandwich Place                               77        77         77
# Scandinavian Restaurant                       2         2          2
# Seafood Restaurant                           27        27         27
# Snack Place                                  91        91         91
# Soup Place                                   23        23         23
# South American Restaurant                    33        33         33
# South Indian Restaurant                       1         1          1
# Southern / Soul Food Restaurant               4         4          4
# Spanish Restaurant                           10        10         10
# Steakhouse                                   31        31         31
# Sushi Restaurant                             50        50         50
# Swiss Restaurant                              4         4          4
# Szechuan Restaurant                           2         2          2
# Taco Place                                    6         6          6
# Tapas Restaurant                             22        22         22
# Thai Restaurant                              58        58         58
# Theme Restaurant                              2         2          2
# Tibetan Restaurant                            5         5          5
# Turkish Restaurant                           64        64         64
# Vegetarian / Vegan Restaurant                39        39         39
# Vietnamese Restaurant                         7         7          7
#
#                                  VenueName  VenueLatitude  VenueLongitude
# VenueCategory
# Afghan Restaurant                        2              2               2
# African Restaurant                      22             22              22
# American Restaurant                      4              4               4
# Argentinian Restaurant                  11             11              11
# Asian Restaurant                        46             46              46
# Australian Restaurant                    3              3               3
# Austrian Restaurant                      4              4               4
# BBQ Joint                               15             15              15
# Bagel Shop                              51             51              51
# Bakery                                 158            158             158
# Belgian Restaurant                       2              2               2
# Bistro                                  42             42              42
# Brasserie                                1              1               1
# Brazilian Restaurant                     5              5               5
# Breakfast Spot                         112            112             112
# Buffet                                   7              7               7
# Burger Joint                            51             51              51
# Burrito Place                            3              3               3
# Cafeteria                                7              7               7
# Café                                   201            201             201
# Cajun / Creole Restaurant                1              1               1
# Caribbean Restaurant                     9              9               9
# Caucasian Restaurant                     1              1               1
# Chinese Restaurant                      66             66              66
# Cigkofte Place                           1              1               1
# Comfort Food Restaurant                  6              6               6
# Creperie                                18             18              18
# Deli / Bodega                           48             48              48
# Dim Sum Restaurant                       2              2               2
# Diner                                   26             26              26
# Doner Restaurant                         6              6               6
# Donut Shop                               7              7               7
# Dumpling Restaurant                      1              1               1
# Dutch Restaurant                        11             11              11
# Eastern European Restaurant              2              2               2
# Empanada Restaurant                      1              1               1
# Ethiopian Restaurant                     6              6               6
# Falafel Restaurant                      13             13              13
# Fast Food Restaurant                    29             29              29
# Fish & Chips Shop                       12             12              12
# Fondue Restaurant                        1              1               1
# Food                                     3              3               3
# Food Court                               4              4               4
# Food Stand                               7              7               7
# Food Truck                              15             15              15
# French Restaurant                       73             73              73
# Fried Chicken Joint                      2              2               2
# Friterie                                 9              9               9
# Gastropub                               55             55              55
# German Restaurant                        4              4               4
# Greek Restaurant                        33             33              33
# Himalayan Restaurant                     1              1               1
# Indian Chinese Restaurant                1              1               1
# Indian Restaurant                       32             32              32
# Indonesian Restaurant                   65             65              65
# Irish Pub                                3              3               3
# Italian Restaurant                     211            211             211
# Japanese Restaurant                     44             44              44
# Kebab Restaurant                         1              1               1
# Korean Restaurant                        1              1               1
# Latin American Restaurant                5              5               5
# Lebanese Restaurant                      1              1               1
# Malay Restaurant                         7              7               7
# Mediterranean Restaurant                50             50              50
# Mexican Restaurant                      18             18              18
# Middle Eastern Restaurant               25             25              25
# Modern European Restaurant              10             10              10
# Molecular Gastronomy Restaurant          3              3               3
# Moroccan Restaurant                      9              9               9
# Noodle House                             5              5               5
# North Indian Restaurant                  5              5               5
# Paella Restaurant                        2              2               2
# Persian Restaurant                       1              1               1
# Peruvian Restaurant                      1              1               1
# Pet Café                                 2              2               2
# Pizza Place                            115            115             115
# Portuguese Restaurant                    2              2               2
# Ramen Restaurant                        16             16              16
# Restaurant                             346            346             346
# Salad Place                             19             19              19
# Sandwich Place                          77             77              77
# Scandinavian Restaurant                  2              2               2
# Seafood Restaurant                      27             27              27
# Snack Place                             91             91              91
# Soup Place                              23             23              23
# South American Restaurant               33             33              33
# South Indian Restaurant                  1              1               1
# Southern / Soul Food Restaurant          4              4               4
# Spanish Restaurant                      10             10              10
# Steakhouse                              31             31              31
# Sushi Restaurant                        50             50              50
# Swiss Restaurant                         4              4               4
# Szechuan Restaurant                      2              2               2
# Taco Place                               6              6               6
# Tapas Restaurant                        22             22              22
# Thai Restaurant                         58             58              58
# Theme Restaurant                         2              2               2
# Tibetan Restaurant                       5              5               5
# Turkish Restaurant                      64             64              64
# Vegetarian / Vegan Restaurant           39             39              39
# Vietnamese Restaurant                    7              7               7

# %% [markdown]
# #### Which neighbourhood has the max number of restaurants

# %%
venues_sort = venues_df.groupby(['Neighbourhoods'])['VenueCategory'].count() \
                             .reset_index(name='Restaurant count') \
                             .sort_values(['Restaurant count'], ascending=False) \
                             .head(10)
#top 10 neighbourhoods with maximum number of restaurants
venues_sort = pd.DataFrame(venues_sort)
venues_sort
# Out:
#            Neighbourhoods  Restaurant count
# 66              Oude Pijp               100
# 19                De Pijp               100
# 38                Jordaan               100
# 20              De Wallen                97
# 13  Burgwallen Oude Zijde                97
# 2      Amsterdam Oud-West                77
# 26  Frederik Hendrikbuurt                68
# 37             Jodenbuurt                65
# 85             Trompbuurt                65
# 32    Hoofddorppleinbuurt                57

# %% [markdown]
# #### Lets see how many Indian restaurants are there in each of the neighbourhoods in top 10 list

# %%
top10_neighbourhoodlist = []
top10_neighbourhoodlist = venues_sort['Neighbourhoods'].tolist()
top10_venues_df = venues_df.loc[venues_df['Neighbourhoods'].isin(top10_neighbourhoodlist)]
top10_list = venues_df.loc[venues_df['Neighbourhoods'].isin(top10_neighbourhoodlist)]
top10_venues_df = top10_venues_df.loc[top10_venues_df['VenueCategory']=='Indian Restaurant']
top10_venues_df
# Out:
#              Neighbourhoods   Latitude  Longitude         VenueName  \
# 132      Amsterdam Oud-West  52.365390   4.870220  Tandoori Express
# 347   Burgwallen Oude Zijde  52.371690   4.897240        Koh-I-Noor
# 421   Burgwallen Oude Zijde  52.371690   4.897240         Kamasutra
# 424   Burgwallen Oude Zijde  52.371690   4.897240            Gandhi
# 590                 De Pijp  52.356250   4.890570         Taj Mahal
# 595                 De Pijp  52.356250   4.890570       Balti House
# 622                 De Pijp  52.356250   4.890570  Restaurant Surya
# 680               De Wallen  52.371690   4.897240        Koh-I-Noor
# 754               De Wallen  52.371690   4.897240         Kamasutra
# 757               De Wallen  52.371690   4.897240            Gandhi
# 927   Frederik Hendrikbuurt  52.378646   4.877719        Shah Jahan
# 1204             Jodenbuurt  52.363000   4.884360             Mayur
# 1237             Jodenbuurt  52.363000   4.884360        Bombay Inn
# 1276                Jordaan  52.376870   4.879270        Shah Jahan
# 1283                Jordaan  52.376870   4.879270        Koh-I-Noor
# 1890              Oude Pijp  52.356250   4.890570         Taj Mahal
# 1895              Oude Pijp  52.356250   4.890570       Balti House
# 1922              Oude Pijp  52.356250   4.890570  Restaurant Surya
# 2348             Trompbuurt  52.363000   4.884360             Mayur
# 2381             Trompbuurt  52.363000   4.884360        Bombay Inn
#
#       VenueLatitude  VenueLongitude      VenueCategory
# 132       52.367866        4.874061  Indian Restaurant
# 347       52.371892        4.892994  Indian Restaurant
# 421       52.375108        4.898459  Indian Restaurant
# 424       52.375384        4.894932  Indian Restaurant
# 590       52.357233        4.890989  Indian Restaurant
# 595       52.354743        4.888495  Indian Restaurant
# 622       52.353228        4.893747  Indian Restaurant
# 680       52.371892        4.892994  Indian Restaurant
# 754       52.375108        4.898459  Indian Restaurant
# 757       52.375384        4.894932  Indian Restaurant
# 927       52.377952        4.883446  Indian Restaurant
# 1204      52.362330        4.886113  Indian Restaurant
# 1237      52.365103        4.882919  Indian Restaurant
# 1276      52.377952        4.883446  Indian Restaurant
# 1283      52.374063        4.883732  Indian Restaurant
# 1890      52.357233        4.890989  Indian Restaurant
# 1895      52.354743        4.888495  Indian Restaurant
# 1922      52.353228        4.893747  Indian Restaurant
# 2348      52.362330        4.886113  Indian Restaurant
# 2381      52.365103        4.882919  Indian Restaurant

# %% [markdown]
# #### Number of Indian restaurants in the top 10 neighbourhoods.

# %%
top10_venues_indian = top10_venues_df.groupby(['Neighbourhoods']).size() \
                    .reset_index(name='Indian Restaurant count') \
                    .sort_values(['Indian Restaurant count'], ascending=False)
top10_venues_indian = pd.DataFrame(top10_venues_indian)
top10_venues_indian
# Out:
#           Neighbourhoods  Indian Restaurant count
# 1  Burgwallen Oude Zijde                        3
# 2                De Pijp                        3
# 3              De Wallen                        3
# 7              Oude Pijp                        3
# 5             Jodenbuurt                        2
# 6                Jordaan                        2
# 8             Trompbuurt                        2
# 0     Amsterdam Oud-West                        1
# 4  Frederik Hendrikbuurt                        1

# %% [markdown]
# #### Count of all the restaurants and Indian restaurants in each of the top 10 neightbourhoods

# %%
merge_df = pd.merge(venues_sort,top10_venues_indian,how='inner',on='Neighbourhoods')
merge_df
# Out:
#           Neighbourhoods  Restaurant count  Indian Restaurant count
# 0              Oude Pijp               100                        3
# 1                De Pijp               100                        3
# 2                Jordaan               100                        2
# 3              De Wallen                97                        3
# 4  Burgwallen Oude Zijde                97                        3
# 5     Amsterdam Oud-West                77                        1
# 6  Frederik Hendrikbuurt                68                        1
# 7             Jodenbuurt                65                        2
# 8             Trompbuurt                65                        2

# %% [markdown]
# As you can see, top 5 neighbourhoods already have atleast 2 or 3 Indian restaurants, whereas bottom 4 have 1 or 2 Indian restaurants. It may or may not be a wise decision to open Indian restaurants in top 5 or neighbourhoods where there are minimum 2 Indian restaurants as there is more competition. So even if someone has to open an Indian restaurant he should go either with <b>Amsterdam Oud-West or Frederik Hendrikbuurt</b> because there is only 1 Indian restaurant in each of these neighbourhoods.

# %% [markdown]
# ### Lets analyze each neighbourhood in the top 10 list

# %%
# one hot encoding
venues_onehot = pd.get_dummies(top10_list[['VenueCategory']], prefix="", prefix_sep="")

# add Neighbourhoods column back to dataframe
venues_onehot['Neighbourhoods'] = top10_list['Neighbourhoods'] 

# move neighbourhoods column to the first column
fixed_columns = [venues_onehot.columns[-1]] + list(venues_onehot.columns[:-1])
venues_onehot = venues_onehot[fixed_columns]

venues_onehot.head()
# Out:
#         Neighbourhoods  Afghan Restaurant  American Restaurant  \
# 57  Amsterdam Oud-West                  0                    0
# 58  Amsterdam Oud-West                  0                    0
# 59  Amsterdam Oud-West                  0                    0
# 60  Amsterdam Oud-West                  0                    0
# 61  Amsterdam Oud-West                  0                    0
#
#     Argentinian Restaurant  Asian Restaurant  Australian Restaurant  \
# 57                       0                 0                      0
# 58                       0                 0                      0
# 59                       0                 0                      0
# 60                       0                 0                      0
# 61                       0                 0                      0
#
#     BBQ Joint  Bagel Shop  Bakery  Belgian Restaurant  Bistro  \
# 57          0           0       0                   0       0
# 58          0           0       0                   0       0
# 59          0           0       0                   0       0
# 60          0           0       0                   0       0
# 61          0           0       0                   0       0
#
#     Brazilian Restaurant  Breakfast Spot  Burger Joint  Burrito Place  Café  \
place  South American Restaurant  Southern / Soul Food Restaurant  \
# 0    0.000000                   0.000000                         0.000000
# 1    0.010309                   0.010309                         0.000000
# 2    0.000000                   0.030000                         0.000000
# 3    0.010309                   0.010309                         0.000000
# 4    0.000000                   0.014706                         0.000000
# 5    0.000000                   0.000000                         0.017544
# 6    0.015385                   0.000000                         0.000000
# 7    0.000000                   0.010000                         0.000000
# 8    0.000000                   0.030000                         0.000000
# 9    0.015385                   0.000000                         0.000000
#
#    Spanish Restaurant  Steakhouse  Sushi Restaurant  Swiss Restaurant  \
# 0            0.012987    0.000000          0.012987          0.000000
# 1            0.000000    0.030928          0.030928          0.010309
# 2            0.010000    0.010000          0.030000          0.000000
# 3            0.000000    0.030928          0.030928          0.010309
# 4            0.029412    0.014706          0.029412          0.000000
# 5            0.000000    0.017544          0.035088          0.000000
# 6            0.000000    0.046154          0.030769          0.000000
# 7            0.020000    0.020000          0.020000          0.000000
# 8            0.010000    0.010000          0.030000          0.000000
# 9            0.000000    0.046154          0.030769          0.000000
#
#    Szechuan Restaurant  Taco Place  Tapas Restaurant  Thai Restaurant  \
# 0             0.000000    0.000000          0.012987         0.012987
# 1             0.010309    0.000000          0.010309         0.041237
# 2             0.000000    0.000000          0.000000         0.040000
# 3             0.010309    0.000000          0.010309         0.041237
# 4             0.000000    0.014706          0.014706         0.073529
# 5             0.000000    0.000000          0.000000         0.035088
# 6             0.000000    0.000000          0.000000         0.000000
# 7             0.000000    0.010000          0.020000         0.050000
# 8             0.000000    0.000000          0.000000         0.040000
# 9             0.000000    0.000000          0.000000         0.000000
#
#    Theme Restaurant  Tibetan Restaurant  Turkish Restaurant  \
# 0          0.000000            0.012987            0.025974
# 1          0.000000            0.010309            0.000000
# 2          0.000000            0.000000            0.000000
# 3          0.000000            0.010309            0.000000
# 4          0.000000            0.000000            0.000000
# 5          0.000000            0.000000            0.017544
# 6          0.015385            0.000000            0.015385
# 7          0.000000            0.000000            0.040000
# 8          0.000000            0.000000            0.000000
# 9          0.015385            0.000000            0.015385
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant
# 0                       0.051948               0.012987
# 1                       0.000000               0.000000
# 2                       0.040000               0.010000
# 3                       0.000000               0.000000
# 4                       0.014706               0.000000
# 5                       0.017544               0.017544
# 6                       0.015385               0.000000
# 7                       0.000000               0.000000
# 8                       0.040000               0.010000
# 9                       0.015385               0.000000

# %%
venues_grouped.shape
# Out:
# (10, 80)

# %% [markdown]
# #### Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in venues_grouped['Neighbourhoods']:
    print("----"+hood+"----")
    temp = venues_grouped[venues_grouped['Neighbourhoods'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Amsterdam Oud-West----
#                            venue  freq
# 0                           Café  0.12
# 1                     Restaurant  0.10
# 2             Italian Restaurant  0.08
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                    Pizza Place  0.04
#
#
# ----Burgwallen Oude Zijde----
#                 venue  freq
# 0                Café  0.09
# 1  Chinese Restaurant  0.07
# 2  Italian Restaurant  0.05
# 3              Bakery  0.05
# 4     Thai Restaurant  0.04
#
#
# ----De Pijp----
#                  venue  freq
# 0                 Café  0.06
# 1           Restaurant  0.06
# 2   Italian Restaurant  0.06
# 3  Japanese Restaurant  0.05
# 4    French Restaurant  0.05
#
#
# ----De Wallen----
#                 venue  freq
# 0                Café  0.09
# 1  Chinese Restaurant  0.07
# 2  Italian Restaurant  0.05
# 3              Bakery  0.05
# 4     Thai Restaurant  0.04
#
#
# ----Frederik Hendrikbuurt----
#                 venue  freq
# 0  Italian Restaurant  0.13
# 1     Thai Restaurant  0.07
# 2  Seafood Restaurant  0.06
# 3                Café  0.06
# 4          Restaurant  0.06
#
#
# ----Hoofddorppleinbuurt----
#                 venue  freq
# 0  Italian Restaurant  0.11
# 1                Café  0.09
# 2              Bakery  0.07
# 3      Breakfast Spot  0.05
# 4    Asian Restaurant  0.05
#
#
# ----Jodenbuurt----
#                 venue  freq
# 0          Restaurant  0.12
# 1                Café  0.12
# 2  Italian Restaurant  0.06
# 3      Breakfast Spot  0.06
# 4    Asian Restaurant  0.05
#
#
# ----Jordaan----
#                 venue  freq
# 0                Café  0.11
# 1  Italian Restaurant  0.08
# 2     Thai Restaurant  0.05
# 3      Sandwich Place  0.05
# 4  Turkish Restaurant  0.04
#
#
# ----Oude Pijp----
#                  venue  freq
# 0                 Café  0.06
# 1           Restaurant  0.06
# 2   Italian Restaurant  0.06
# 3  Japanese Restaurant  0.05
# 4    French Restaurant  0.05
#
#
# ----Trompbuurt----
#                 venue  freq
# 0          Restaurant  0.12
# 1                Café  0.12
# 2  Italian Restaurant  0.06
# 3      Breakfast Spot  0.06
# 4    Asian Restaurant  0.05

# %% [markdown]
# As you can see none of the Indian restaurants in each neighbourhood appear in the top 5 list of common venues.

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhoods']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhoods'] = venues_grouped['Neighbourhoods']

for ind in np.arange(venues_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(venues_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.head()
# Out:
#           Neighbourhoods 1st Most Common Venue 2nd Most Common Venue  \
# 0     Amsterdam Oud-West                  Café            Restaurant
# 1  Burgwallen Oude Zijde                  Café    Chinese Restaurant
# 2                De Pijp                  Café            Restaurant
# 3              De Wallen                  Café    Chinese Restaurant
# 4  Frederik Hendrikbuurt    Italian Restaurant       Thai Restaurant
#
#   3rd Most Common Venue          4th Most Common Venue 5th Most Common Venue  \
# 0    Italian Restaurant  Vegetarian / Vegan Restaurant           Pizza Place
# 1    Italian Restaurant                         Bakery         Deli / Bodega
# 2    Italian Restaurant              French Restaurant   Japanese Restaurant
# 3    Italian Restaurant                         Bakery         Deli / Bodega
# 4            Restaurant                           Café    Seafood Restaurant
#
#    6th Most Common Venue          7th Most Common Venue 8th Most Common Venue  \
# 0         Breakfast Spot             Seafood Restaurant                Bakery
# 1        Thai Restaurant                     Restaurant        Sandwich Place
# 2                 Bakery  Vegetarian / Vegan Restaurant        Sandwich Place
# 3        Thai Restaurant                     Restaurant        Sandwich Place
# 4  Indonesian Restaurant                     Bagel Shop                Bakery
#
#       9th Most Common Venue      10th Most Common Venue
# 0  Mediterranean Restaurant  Modern European Restaurant
# 1                Steakhouse           Indian Restaurant
# 2           Thai Restaurant    Mediterranean Restaurant
# 3                Steakhouse           Indian Restaurant
# 4                    Bistro          Spanish Restaurant

# %%
amsterdam_grouped_indian = venues_grouped[["Neighbourhoods","Indian Restaurant"]]

# %%
amsterdam_grouped_indian
# Out:
#           Neighbourhoods  Indian Restaurant
# 0     Amsterdam Oud-West           0.012987
# 1  Burgwallen Oude Zijde           0.030928
# 2                De Pijp           0.030000
# 3              De Wallen           0.030928
# 4  Frederik Hendrikbuurt           0.014706
# 5    Hoofddorppleinbuurt           0.000000
# 6             Jodenbuurt           0.030769
# 7                Jordaan           0.020000
# 8              Oude Pijp           0.030000
# 9             Trompbuurt           0.030769

# %% [markdown]
# ## Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

amsterdam_grouped_clustering = amsterdam_grouped_indian.drop('Neighbourhoods', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(amsterdam_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 1, 1, 1, 2, 0, 1, 3, 1, 1], dtype=int32)

# %%
# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
amsterdam_merged = amsterdam_grouped_indian.copy()

# add clustering labels
amsterdam_merged["Cluster Labels"] = kmeans.labels_

# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
amsterdam_merged = amsterdam_merged.join(amsterdam_df.set_index("Neighbourhoods"), on="Neighbourhoods")

amsterdam_merged.rename(columns={"Neighbourhoods": "Neighbourhoods"}, inplace=True)
amsterdam_merged.head()
# Out:
#           Neighbourhoods  Indian Restaurant  Cluster Labels   Latitude  \
# 0     Amsterdam Oud-West           0.012987               4  52.365390
# 1  Burgwallen Oude Zijde           0.030928               1  52.371690
# 2                De Pijp           0.030000               1  52.356250
# 3              De Wallen           0.030928               1  52.371690
# 4  Frederik Hendrikbuurt           0.014706               2  52.378646
#
#    Longitude
# 0   4.870220
# 1   4.897240
# 2   4.890570
# 3   4.897240
# 4   4.877719

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(amsterdam_merged['Latitude'], amsterdam_merged['Longitude'], amsterdam_merged['Neighbourhoods'], amsterdam_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examine Clusters

# %% [markdown]
# ### cluster 0

# %%
amsterdam_merged.loc[amsterdam_merged['Cluster Labels'] == 0]
# Out:
#         Neighbourhoods  Indian Restaurant  Cluster Labels   Latitude  \
# 5  Hoofddorppleinbuurt                0.0               0  52.351592
#
#    Longitude
# 5   4.850202

# %% [markdown]
# ### cluster 1

# %%
amsterdam_merged.loc[amsterdam_merged['Cluster Labels'] == 1]
# Out:
#           Neighbourhoods  Indian Restaurant  Cluster Labels  Latitude  \
# 1  Burgwallen Oude Zijde           0.030928               1  52.37169
# 2                De Pijp           0.030000               1  52.35625
# 3              De Wallen           0.030928               1  52.37169
# 6             Jodenbuurt           0.030769               1  52.36300
# 8              Oude Pijp           0.030000               1  52.35625
# 9             Trompbuurt           0.030769               1  52.36300
#
#    Longitude
# 1    4.89724
# 2    4.89057
# 3    4.89724
# 6    4.88436
# 8    4.89057
# 9    4.88436

# %% [markdown]
# ### cluster 2

# %%
amsterdam_merged.loc[amsterdam_merged['Cluster Labels'] == 2]
# Out:
#           Neighbourhoods  Indian Restaurant  Cluster Labels   Latitude  \
# 4  Frederik Hendrikbuurt           0.014706               2  52.378646
#
#    Longitude
# 4   4.877719

# %% [markdown]
# ### cluster 3

# %%
amsterdam_merged.loc[amsterdam_merged['Cluster Labels'] == 3]
# Out:
#   Neighbourhoods  Indian Restaurant  Cluster Labels  Latitude  Longitude
# 7        Jordaan               0.02               3  52.37687    4.87927

# %% [markdown]
# ### cluster 4

# %%
amsterdam_merged.loc[amsterdam_merged['Cluster Labels'] == 4]
# Out:
#        Neighbourhoods  Indian Restaurant  Cluster Labels  Latitude  Longitude
# 0  Amsterdam Oud-West           0.012987               4  52.36539    4.87022

# %% [markdown]
# Most of the Indian restaurants are located in cluster 1, whereas there are no Indian restaurants in cluster 0,2,3,4 in the top 10 venues in top 10 neighbourhoods. In my first level analysis, where I had said if someone has to open an Indian restaurant they can open in the following areas: Amsterdam Oud-West, Frederik Hendrikbuurt or Hoofddorppleinbuurt because there are either 0 or 1 Indian restaurant in each of these neighbourhoods (check above, no k-means clustering used). You can even add Jordaan to it but I wont go with because it already has 2 Indian restaurants. I would rather go with Amsterdam Oud-West as it has lowest k-means amonsgt all the clusters and is closer to Amsterdam train st
